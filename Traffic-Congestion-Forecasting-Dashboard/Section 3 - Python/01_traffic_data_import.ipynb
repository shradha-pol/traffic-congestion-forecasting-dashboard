# %% [markdown]
# # Question 1: Import SQL-exported data into Pandas Data Frames

# %% [markdown]
# # Step 1 - Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# # Step 2 - Load CSV File into DataFrame

# %%
df = pd.read_csv("traffic_data_full.csv")

# %% [markdown]
# # Step 3 - Display First 5 Rows

# %%
print(df.head())
# Out:
#   Sensor_ID      Timestamp      Date Day_Name Month  Hour Is_Weekend  \
# 0      S001  1/1/2024 0:00  1/1/2024   Monday   Jan     0         No
# 1      S001  1/1/2024 0:00  1/1/2024   Monday   Jan     0         No
# 2      S001  1/1/2024 0:00  1/1/2024   Monday   Jan     0         No
# 3      S001  1/1/2024 1:00  1/1/2024   Monday   Jan     1         No
# 4      S001  1/1/2024 1:00  1/1/2024   Monday   Jan     1         No
#
#   Peak_Period Location             Road_Segment  ... Weather Weather_Severity  \
# 0    Off-Peak   Mumbai  Eastern Express Highway  ...   Clear                0
# 1    Off-Peak   Mumbai  Eastern Express Highway  ...   Clear                0
# 2    Off-Peak   Mumbai  Eastern Express Highway  ...   Clear                0
# 3    Off-Peak   Mumbai  Eastern Express Highway  ...   Clear                0
# 4    Off-Peak   Mumbai  Eastern Express Highway  ...   Clear                0
#
#   Traffic_Volume  Avg_Speed_kmph  Congestion_Ratio  Congestion_Level  \
# ...

# %% [markdown]
# # Step 4 - Check Dataset Information

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36288 entries, 0 to 36287
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sensor_ID         36288 non-null  object
#  1   Timestamp         36288 non-null  object
#  2   Date              36288 non-null  object
#  3   Day_Name          36288 non-null  object
#  4   Month             36288 non-null  object
#  5   Hour              36288 non-null  int64
#  6   Is_Weekend        36288 non-null  object
#  7   Peak_Period       36288 non-null  object
#  8   Location          36288 non-null  object
#  9   Road_Segment      36288 non-null  object
#  10  Segment_Type      36288 non-null  object
#  11  Vehicle_Type      36288 non-null  object
#  12  Weather           36288 non-null  object
#  13  Weather_Severity  36288 non-null  int64
#  14  Traffic_Volume    36288 non-null  int64
#  15  Avg_Speed_kmph    36288 non-null  float64
# ...

# %% [markdown]
# # Step 5 - Check Dataset Shape

# %%
print(df.shape)
# Out:
# (36288, 22)
